# %% [markdown]
# <a href="https://colab.research.google.com/github/ch835062/raspberry_gemini/blob/main/lesson5/lesson5_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
title: 基礎 Action 範例
author: YourName
version: 1.0
requirements: pydantic
"""

from pydantic import BaseModel


class Action:

    # 設定區（可以在 UI 修改）
    class Valves(BaseModel):
        nickname: str = "xxxxx"

    def __init__(self):
        self.valves = self.Valves()

    async def action(self, body: dict):

        # 讀取設定值
        name = self.valves.nickname

        message = body["messages"][-1]["content"]

        body["messages"][-1]["content"] += f"(您好 {name})"

        return body
